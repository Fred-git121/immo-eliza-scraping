# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import csv

# URL listesi (örnek)
url_list = ["https://immovlan.be/en/detail/apartment/for-sale/1060/sint-gillis/vwd15254","https://immovlan.be/en/detail/apartment/for-sale/1000/brussels/rwc41104"]

# Chrome başlat
driver = webdriver.Chrome()

# CSV dosyasını aç
with open("houses.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["vlan_code", "Price", "Number_of_bedrooms", "Livable surface"])

    for url in url_list:
        driver.get(url)
        time.sleep(3)

        # Cookie izni (ilk sayfada çıkarsa)
        try:
            driver.find_element(By.ID, "didomi-notice-agree-button").click()
            time.sleep(1)
        except:
            pass

        # HTML al ve parse et
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

         # Bilgileri çek
        code_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[1]/div[1]/div/h1/span/span[2]')
        code = code_element.text.strip()
        print("vlan_code:", code)

        price_element = driver.find_element(By.XPATH, '//*[@id="col_top_left"]/div[2]/ul/li[2]/strong')
        price = price_element.text.strip()
        print("Price:", price)

        rooms_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[8]/div/div[2]/div/div[1]/p')
        rooms = rooms_element.text.strip()
        print("Number_of_bedrooms:", rooms)

        area_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[8]/div/div[2]/div/div[2]/p')
        area = area_element.text.strip()
        print("Livable surface:", area)

        # CSV'ye yaz
        writer.writerow([code, price, rooms, area])
        print("Recorded")
# Out:
# vlan_code: VWD15254
# Price: 133
# Number_of_bedrooms: 2
# Livable surface: 133 m²
# Recorded
# vlan_code: RWC41104
# Price: 76
# Number_of_bedrooms: 1
# Livable surface: 76 m²
# Recorded

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import csv

# URL listesi (örnek)
url_list = [
    "https://immovlan.be/en/detail/apartment/for-sale/1060/sint-gillis/vwd15254",
    "https://immovlan.be/en/detail/apartment/for-sale/1000/brussels/rwc41104"
]

# Chrome başlat
driver = webdriver.Chrome()

# CSV dosyasını aç
with open("houses.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["vlan_code", "Price", "Number_of_bedrooms", "Livable surface"])

    for url in url_list:
        driver.get(url)
        time.sleep(3)

        # Cookie izni (ilk sayfada çıkarsa)
        try:
            driver.find_element(By.ID, "didomi-notice-agree-button").click()
            time.sleep(1)
        except:
            pass

        # HTML al ve parse et
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

        # Bilgileri çek
        code_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[1]/div[1]/div/h1/span/span[2]')
        code = code_element.text.strip()
        print("vlan_code:", code)

        price_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[1]/div[1]/div/p/span[1]')
        price = price_element.text.strip()
        print("Price:", price)

        rooms_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[8]/div/div[2]/div/div[1]/p')
        rooms = rooms_element.text.strip()
        print("Number_of_bedrooms:", rooms)

        area_element = driver.find_element(By.XPATH, '//*[@id="main_content"]/div[8]/div/div[2]/div/div[2]/p')
        area = area_element.text.strip()
        print("Livable surface:", area)

        # CSV'ye yaz
        writer.writerow([code, price, rooms, area])
        print("Recorded")

# Tarayıcıyı kapat
driver.quit()
# Out:
# vlan_code: VWD15254
# Price: 475 000 €
# Number_of_bedrooms: 2
# Livable surface: 133 m²
# Recorded
# vlan_code: RWC41104
# Price: 225 000 €
# Number_of_bedrooms: 1
# Livable surface: 76 m²
# Recorded
